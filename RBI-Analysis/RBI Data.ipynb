# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_excel("Flow_of_Financial_Resources_from_Scheduled_Commercial_Banks_to_the_Commercial_Sector.xlsx",header=3)

# %%
data.head()
# Out:
#    Unnamed: 0      Fortnight Ended  Non-food Bank Credit  \
# 0         NaN                    1                  2.00
# 1         NaN  2021-01-15 00:00:00           10553613.28
# 2         NaN  2021-01-01 00:00:00           10603784.51
# 3         NaN  2020-12-18 00:00:00           10456396.67
# 4         NaN  2020-12-04 00:00:00           10408623.56
#
#    Investments in Commercial Paper  Investments in shares  \
# 0                           3.0000                 4.0000
# 1                       72243.0855             87353.1071
# 2                       71586.6473             87967.1143
# 3                       75340.6698             87483.2165
# 4                       79386.3375             87992.8604
#
#    Investments in Bonds/Debentures Total Non-SLR Investments  \
# 0                           5.0000              6 = (3 to 5)
# 1                      580451.5174                    740048
# 2                      584621.0963                    744175
# ...

# %%
data.drop('Unnamed: 0', axis=1,inplace=True)

# %%
data.head()
# Out:
#        Fortnight Ended  Non-food Bank Credit  Investments in Commercial Paper  \
# 0                    1                  2.00                           3.0000
# 1  2021-01-15 00:00:00           10553613.28                       72243.0855
# 2  2021-01-01 00:00:00           10603784.51                       71586.6473
# 3  2020-12-18 00:00:00           10456396.67                       75340.6698
# 4  2020-12-04 00:00:00           10408623.56                       79386.3375
#
#    Investments in shares  Investments in Bonds/Debentures  \
# 0                 4.0000                           5.0000
# 1             87353.1071                      580451.5174
# 2             87967.1143                      584621.0963
# 3             87483.2165                      583302.9654
# 4             87992.8604                      576391.5471
#
#   Total Non-SLR Investments Adjusted Non-food Bank Credit  \
# 0              6 = (3 to 5)                   7 = (2 + 6)
# ...

# %%
data.drop(0,axis=0,inplace=True)

# %%
data.head()
# Out:
#        Fortnight Ended  Non-food Bank Credit  Investments in Commercial Paper  \
# 1  2021-01-15 00:00:00          1.055361e+07                       72243.0855
# 2  2021-01-01 00:00:00          1.060378e+07                       71586.6473
# 3  2020-12-18 00:00:00          1.045640e+07                       75340.6698
# 4  2020-12-04 00:00:00          1.040862e+07                       79386.3375
# 5  2020-11-20 00:00:00          1.034592e+07                       86030.5395
#
#    Investments in shares  Investments in Bonds/Debentures  \
# 1             87353.1071                      580451.5174
# 2             87967.1143                      584621.0963
# 3             87483.2165                      583302.9654
# 4             87992.8604                      576391.5471
# 5             88079.6646                      571644.7476
#
#   Total Non-SLR Investments Adjusted Non-food Bank Credit  \
# 1                    740048                   1.12937e+07
# ...

# %%
data.isna().sum()
# Out:
# Fortnight Ended                    0
# Non-food Bank Credit               0
# Investments in Commercial Paper    0
# Investments in shares              0
# Investments in Bonds/Debentures    0
# Total Non-SLR Investments          0
# Adjusted Non-food Bank Credit      0
#  Y-o-Y Growth in (7) (%)           0
# dtype: int64

# %%
data.shape
# Out:
# (99, 8)

# %%
data.index=data['Fortnight Ended']

# %%
data.head()
# Out:
#                      Fortnight Ended  Non-food Bank Credit  \
# Fortnight Ended
# 2021-01-15       2021-01-15 00:00:00          1.055361e+07
# 2021-01-01       2021-01-01 00:00:00          1.060378e+07
# 2020-12-18       2020-12-18 00:00:00          1.045640e+07
# 2020-12-04       2020-12-04 00:00:00          1.040862e+07
# 2020-11-20       2020-11-20 00:00:00          1.034592e+07
#
#                  Investments in Commercial Paper  Investments in shares  \
# Fortnight Ended
# 2021-01-15                            72243.0855             87353.1071
# 2021-01-01                            71586.6473             87967.1143
# 2020-12-18                            75340.6698             87483.2165
# 2020-12-04                            79386.3375             87992.8604
# 2020-11-20                            86030.5395             88079.6646
#
#                  Investments in Bonds/Debentures Total Non-SLR Investments  \
# Fortnight Ended
# ...

# %%
data.drop('Fortnight Ended',axis=1,inplace=True)

# %%
data.head()
# Out:
#                  Non-food Bank Credit  Investments in Commercial Paper  \
# Fortnight Ended
# 2021-01-15               1.055361e+07                       72243.0855
# 2021-01-01               1.060378e+07                       71586.6473
# 2020-12-18               1.045640e+07                       75340.6698
# 2020-12-04               1.040862e+07                       79386.3375
# 2020-11-20               1.034592e+07                       86030.5395
#
#                  Investments in shares  Investments in Bonds/Debentures  \
# Fortnight Ended
# 2021-01-15                  87353.1071                      580451.5174
# 2021-01-01                  87967.1143                      584621.0963
# 2020-12-18                  87483.2165                      583302.9654
# 2020-12-04                  87992.8604                      576391.5471
# 2020-11-20                  88079.6646                      571644.7476
#
# ...

# %%
#making a line plot for column values (columns used ->[Investments in Commercial Paper,Investments in shares,Investments in Bonds/Debentures]

data['Investments in Commercial Paper'].plot(label='Investments in Commercial Paper',figsize=(12,8),title="Investments")
data['Investments in shares'].plot(label='Investments in shares',figsize=(12,8),title="Investments")
data['Investments in Bonds/Debentures'].plot(label='Investments in Bonds/Debentures',figsize=(12,8),title="Investments")
plt.legend()

# %%
#making a new column named "Total Investments" that is the sum of 3 different columns as shown below
data['Total Investments']=data['Investments in Commercial Paper']+data['Investments in shares']+data['Investments in Bonds/Debentures']

# %%
data['Total Investments'].plot(label='Total Investments',figsize=(12,8),title="Total Investments")
# Out:
# <AxesSubplot:title={'center':'Total Investments'}, xlabel='Fortnight Ended'>

# %%
data['Total Investments'].plot(kind='bar',figsize=(12,8),title='Total Investment')
# Out:
# <AxesSubplot:title={'center':'Total Investment'}, xlabel='Fortnight Ended'>

# %%
data['Total Investments'].plot(kind='bar',figsize=(12,8),title='Total Investment')
# Out:
# <AxesSubplot:title={'center':'Total Investment'}, xlabel='Fortnight Ended'>

# %%
data.columns
# Out:
# Index(['Non-food Bank Credit', 'Investments in Commercial Paper',
#        'Investments in shares', 'Investments in Bonds/Debentures',
#        'Total Non-SLR Investments', 'Adjusted Non-food Bank Credit',
#        ' Y-o-Y Growth in (7) (%)', 'Total Investments'],
#       dtype='object')

# %%
data[' Y-o-Y Growth in (7) (%)'].plot(figsize=(12,8),title="Growth")
# Out:
# <AxesSubplot:title={'center':'Growth'}, xlabel='Fortnight Ended'>

# %%
y=data[' Y-o-Y Growth in (7) (%)']
x=data.drop(' Y-o-Y Growth in (7) (%)',axis=1)

# %%
x.corrwith(y).plot.bar(figsize=(20,10),title="Correlation with response variable",fontsize=15,rot=45,grid=True)
# Out:
# <AxesSubplot:title={'center':'Correlation with response variable'}>

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
data.head()
# Out:
#                  Non-food Bank Credit  Investments in Commercial Paper  \
# Fortnight Ended
# 2021-01-15               1.055361e+07                       72243.0855
# 2021-01-01               1.060378e+07                       71586.6473
# 2020-12-18               1.045640e+07                       75340.6698
# 2020-12-04               1.040862e+07                       79386.3375
# 2020-11-20               1.034592e+07                       86030.5395
#
#                  Investments in shares  Investments in Bonds/Debentures  \
# Fortnight Ended
# 2021-01-15                  87353.1071                      580451.5174
# 2021-01-01                  87967.1143                      584621.0963
# 2020-12-18                  87483.2165                      583302.9654
# 2020-12-04                  87992.8604                      576391.5471
# 2020-11-20                  88079.6646                      571644.7476
#
# ...

# %%
from sklearn.preprocessing import StandardScaler #StandardScaler function of sklearn is used to scale down values of dataframe between 0 and 1

sc=StandardScaler() 
df=sc.fit_transform(data)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y)

# %%
from tpot import TPOTRegressor
# Out:
# C:\Users\adira\anaconda3\lib\site-packages\tpot\builtins\__init__.py:36: UserWarning: Warning: optional dependency `torch` is not available. - skipping import of NN models.
#   warnings.warn("Warning: optional dependency `torch` is not available. - skipping import of NN models.")

# %%
from sklearn.metrics import roc_auc_score

# %%
tpot=TPOTRegressor(
    generations=5,
    population_size=50,
    verbosity=2,
)
tpot.fit(x_train,y_train)
# Out:
# ...
# Generation 1 - Current best internal CV score: -0.5716189323326093
#
# Generation 2 - Current best internal CV score: -0.5716189323326093
#
# Generation 3 - Current best internal CV score: -0.5716061561339039
#
# Generation 4 - Current best internal CV score: -0.49796808576180507
#
# Generation 5 - Current best internal CV score: -0.49796808576180507
#
# Best pipeline: AdaBoostRegressor(DecisionTreeRegressor(ZeroCount(input_matrix), max_depth=2, min_samples_leaf=4, min_samples_split=18), learning_rate=1.0, loss=linear, n_estimators=100)
# TPOTRegressor(generations=5, population_size=50, verbosity=2)

# %%
tpot_pred=tpot.predict(x_test)

# %%
tpot_pred
# Out:
# array([ 7.43001025,  6.96386314,  7.95539411,  6.69830505, 12.43438721,
#        11.6668438 ,  5.79742292, 14.71727442, 11.6668438 ,  5.79742292,
#         8.13133345, 11.86368091, 11.82232273,  7.07207158, 13.16576204,
#         6.13971477,  5.79742292,  6.84446023,  7.21257397,  6.24518087,
#        13.43457576,  7.95303949,  9.04747198, 11.86368091,  7.26059032])

# %%
from sklearn.ensemble import AdaBoostRegressor

# %%
regr=AdaBoostRegressor(random_state=0,n_estimators=100)

# %%
regr.fit(x_train,y_train)
# Out:
# AdaBoostRegressor(n_estimators=100, random_state=0)

# %%
y_pred=regr.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_pred,y_test)
# Out:
# 1.6182635592497792

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
regr1=RandomForestRegressor(random_state=0,n_estimators=100)
regr1.fit(x_train,y_train)
y_pred1=regr1.predict(x_test)

# %%
mean_squared_error(y_pred1,y_test)
# Out:
# 1.9418733708258435
